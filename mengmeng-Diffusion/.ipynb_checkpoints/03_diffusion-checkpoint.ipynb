# %%
import json
import os 
import glob
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader

# %%
class LazyDatasetList(Dataset):
    def __init__(self, data_files, transform=None, time_interval=timedelta(minutes=10)):
        """
        Custom PyTorch Dataset for loading time-sequenced data.

        Args:
            data_files (list): List of file paths (each file contains a tensor).
            transform (callable, optional): Optional transform to apply to each tensor.
            time_interval (timedelta): Expected time gap between consecutive files.
        """
        
        # Store inputs
        self.data_files = data_files
        self.transform = transform
        self.time_interval = time_interval

        # Format expected in filenames (e.g. "202101010040")
        self.time_format = "%Y%m%d%H%M"

        # Dictionary mapping datetime -> file path
        self.time_to_file = {}

        # Extract timestamps from filenames and build mapping
        for f in self.data_files:
            # Get filename without extension
            ts = os.path.splitext(os.path.basename(f))[0]

            try:
                # Convert filename string to datetime object
                dt = datetime.strptime(ts, self.time_format)

                # Store mapping
                self.time_to_file[dt] = f

            except ValueError:
                # Skip files that don't match expected timestamp format
                continue

        # Sort all valid timestamps
        sorted_times = sorted(self.time_to_file.keys())

        # Build sequences of 4 time steps: [t-3, t-2, t-1, t]
        self.time_list = []

        for t in sorted_times:
            # Define previous time steps
            next_t = t - self.time_interval       # t-1
            next_t_2 = next_t - self.time_interval # t-2
            next_t_3 = next_t_2 - self.time_interval # t-3

            # Only keep sequences where ALL previous timesteps exist
            if (
                next_t in self.time_to_file and
                next_t_2 in self.time_to_file and
                next_t_3 in self.time_to_file
            ):
                # Store tuple of file paths for this sequence
                self.time_list.append((
                    self.time_to_file[t],        # current time (t)
                    self.time_to_file[next_t],   # t-1
                    self.time_to_file[next_t_2], # t-2
                    self.time_to_file[next_t_3]  # t-3
                ))

    def __len__(self):
        """
        Total number of valid 4-step sequences in the dataset.
        """
        return len(self.time_list)

    def __getitem__(self, idx):
        """
        Load a single sample (sequence of 4 timesteps).

        Returns:
            dict:
                'data': Tensor of shape (4, ...)
                'source': String listing filenames used
        """

        # Get file paths for this sequence
        f_t, f_t_1, f_t_2, f_t_3 = self.time_list[idx]

        # Create a string identifying the source files
        full_str = f'{os.path.basename(f_t_3)},{os.path.basename(f_t_2)},{os.path.basename(f_t_1)},{os.path.basename(f_t)}'

        # Load data for each timestep
        data_list = []

        # IMPORTANT: note the order is [t-3, t-2, t-1, t]
        for t_step in [f_t_3, f_t_2, f_t_1, f_t]:

            # Load tensor from file
            data = torch.load(t_step)

            # Add a channel dimension (e.g. from HxW → 1xHxW)
            data = data.unsqueeze(0)

            # Apply optional transform (e.g. normalization)
            if self.transform:
                data = self.transform(data)

            data_list.append(data)

        # Stack tensors along time dimension → shape (4, C, H, W) typically
        data = torch.cat(data_list, dim=0)

        return {
            'data': data,
            'source': full_str
        }

# %%
class MinMaxToMinusOneOne:
    def __init__(self, min_vals, max_vals):
        """
        Transform that scales data from original range → [-1, 1].

        Args:
            min_vals (list or array): Minimum value for each channel
            max_vals (list or array): Maximum value for each channel
        """

        # Convert min/max lists to tensors and reshape to [C, 1, 1]
        # This allows broadcasting across height (H) and width (W)
        self.min_vals = torch.tensor(min_vals).view(-1, 1, 1)
        self.max_vals = torch.tensor(max_vals).view(-1, 1, 1)
        
    def __call__(self, x):
        """
        Apply normalization.

        Args:
            x (Tensor): Shape [C, H, W]

        Returns:
            Tensor: Normalized to [-1, 1]
        """

        # Step 1: Scale from original range → [0, 1]
        # Formula: (x - min) / (max - min)
        # 1e-6 prevents division by zero if max == min
        x = (x - self.min_vals) / (self.max_vals - self.min_vals + 1e-6)

        # Step 2: Scale from [0, 1] → [-1, 1]
        # Formula: x * 2 - 1
        return x * 2.0 - 1.0

# %%
# Directory containing your data files and normalization stats
input_dir = '/scratch/nf33/cd3022/pyearth'


# -----------------------------
# Load saved min/max statistics
# -----------------------------
# These were likely computed beforehand across the dataset
# and saved to ensure consistent normalization during training

with open(os.path.join(input_dir, 'min_max.json'), 'r') as f:
    stats = json.load(f)

    # Extract min and max values for each channel
    # Convert to float32 tensors for use in PyTorch
    min_vals = torch.tensor(stats['min'], dtype=torch.float32)
    max_vals = torch.tensor(stats['max'], dtype=torch.float32)


# -----------------------------
# Collect all data files
# -----------------------------
# Finds all .pt files (PyTorch tensors) in the directory
# Each file is expected to correspond to a single timestep

data_files = sorted(glob.glob(os.path.join(input_dir, '*.pt')))


# -----------------------------
# Create dataset
# -----------------------------
# This:
# 1. Builds time sequences (t-3 → t)
# 2. Applies normalization transform
# 3. Prepares data for training

train_dataset = LazyDatasetList(
    data_files,
    transform=MinMaxToMinusOneOne(min_vals, max_vals)
)
# Out:
# /jobfs/163400163.gadi-pbs/ipykernel_2551451/2377728656.py:13: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.min_vals = torch.tensor(min_vals).view(-1, 1, 1)
# /jobfs/163400163.gadi-pbs/ipykernel_2551451/2377728656.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.max_vals = torch.tensor(max_vals).view(-1, 1, 1)

# %%
# -----------------------------
# Create DataLoader
# -----------------------------
# Wraps the dataset to:
# - create batches
# - optionally shuffle data
# - load data in parallel (num_workers)

loader = DataLoader(
    train_dataset,
    batch_size=2,   # number of samples (time sequences) per batch
    shuffle=False,  # no shuffling (important for debugging; may change later for training)
    num_workers=2   # number of CPU processes used for loading data
)

# %%
# -----------------------------
# Get one batch from the loader
# -----------------------------
# iter(loader) creates an iterator
# next(...) grabs the first batch

data_sample = next(iter(loader))

# -----------------------------
# Inspect tensor shape
# -----------------------------
# Expected shape:
# B = batch size
# T = number of timesteps (4 in your dataset)
# C = channels (likely 1)
# H, W = spatial dimensions
'''
# CURRENTLY SINGLE CHANNEL, SO NO CHANNEL DIM
'''
print(data_sample['data'].shape)  # e.g. (B, T, C, H, W)
# Out:
# Traceback (most recent call last):
#   File "/opt/conda/envs/pet/lib/python3.11/multiprocessing/util.py", line 300, in _run_finalizers
#     finalizer()
#   File "/opt/conda/envs/pet/lib/python3.11/multiprocessing/util.py", line 224, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/pet/lib/python3.11/multiprocessing/util.py", line 133, in _remove_temp_dir
#     rmtree(tempdir)
#   File "/opt/conda/envs/pet/lib/python3.11/shutil.py", line 738, in rmtree
#     onerror(os.rmdir, path, sys.exc_info())
#   File "/opt/conda/envs/pet/lib/python3.11/shutil.py", line 736, in rmtree
#     os.rmdir(path, dir_fd=dir_fd)
# OSError: [Errno 39] Directory not empty: '/jobfs/163400163.gadi-pbs/pymp-5xwbdgsr'
# torch.Size([2, 4, 64, 64])

# %%
# -----------------------------
# Inspect metadata
# -----------------------------
# 'source' contains filenames used to build each sample

print(len(data_sample['source']))  # should equal batch_size (2)


# Print the actual file sequences
print(data_sample['source'])
# Out:
# 2
# ['202101010000.pt,202101010010.pt,202101010020.pt,202101010030.pt', '202101010010.pt,202101010020.pt,202101010030.pt,202101010040.pt']

# %%
# -----------------------------
# Create dataset WITHOUT normalization
# -----------------------------
# This is important: we skip the transform so we can inspect
# the raw values (e.g. actual irradiance, temperature, etc.)

plt_dataset = LazyDatasetList(data_files)


# -----------------------------
# Create DataLoader
# -----------------------------
loader = DataLoader(
    plt_dataset,
    batch_size=2,
    shuffle=False,
    num_workers=2
)


# -----------------------------
# Get one batch
# -----------------------------
data_sample = next(iter(loader))


# -----------------------------
# Plot a single image
# -----------------------------
# Indexing:
# [batch, time, height, width]

plt.imshow(data_sample['data'][0, 0, :, :], cmap='viridis')
plt.colorbar()

plt.title(data_sample['source'][0])
# Out:
# Text(0.5, 1.0, '202101010000.pt,202101010010.pt,202101010020.pt,202101010030.pt')

# %%
data_sample['data'][0, 0, :, :]
# Out:
# tensor([[514.6800, 579.3400, 400.1500,  ..., 700.3100, 710.6900, 702.9500],
#         [562.8800, 543.2800, 419.7200,  ..., 685.2400, 693.5600, 685.7100],
#         [464.9400, 483.6200, 487.3300,  ..., 662.4600, 717.6800, 662.1800],
#         ...,
#         [ 92.8100, 115.7400, 176.2900,  ..., 227.0900, 224.3600, 227.1500],
#         [208.9300, 214.2600, 223.5300,  ..., 228.3400, 224.3600, 227.1500],
#         [226.6900, 226.1600, 237.9500,  ..., 240.8500, 240.5600, 233.1400]],
#        dtype=torch.float64)

# %%
#check data equality based on source labels
original = torch.load('/scratch/nf33/cd3022/pyearth/202101010000.pt')
torch.equal(original, data_sample['data'][0, 0, :, :])
# Out:
# True

# %%
from dataclasses import dataclass
from torchvision import transforms
import torch
from diffusers import UNet2DModel
from diffusers import DDPMScheduler
import torch.nn.functional as F
from diffusers.optimization import get_cosine_schedule_with_warmup
from diffusers import DDPMPipeline
import os
from accelerate import Accelerator
from tqdm.auto import tqdm
from accelerate import notebook_launcher

# %%
@dataclass
class TrainingConfig:
    """
    Configuration for training the diffusion model.
    Acts as a central place to control hyperparameters and settings.
    """

    # -----------------------------
    # Model architecture
    # -----------------------------
    in_channels = 4
    # IMPORTANT:
    # Your dataset produces (B, 4, 64, 64)
    # → 4 timesteps are treated as input channels

    out_channels = 1
    # Model predicts a single channel
    # Typically: predicted noise for one target frame


    image_size = 64
    # Spatial resolution (64x64 images)


    # -----------------------------
    # Training setup
    # -----------------------------
    train_batch_size = 2
    # Matches your DataLoader

    num_epochs = 2500
    # Very high — diffusion models need lots of training


    gradient_accumulation_steps = 100
    # KEY IDEA:
    # Simulates a much larger batch size:
    #
    # effective batch size = 2 × 100 = 200
    #
    # Useful when GPU memory is limited


    learning_rate = 1e-4
    # Standard for diffusion models


    lr_warmup_steps = 600
    # Gradually increase LR at start
    # Helps stabilise early training


    # -----------------------------
    # Saving & checkpoints
    # -----------------------------
    save_model_epochs = 500
    # Save model every 500 epochs

    output_dir = "/scratch/nf33/cd3022/pyearth/model"
    # Where checkpoints + outputs are stored

    resume_from_checkpoint = False
    # If True → continue training from saved model

    overwrite_output_dir = True
    # If True → deletes previous outputs


    # -----------------------------
    # Precision / performance
    # -----------------------------
    mixed_precision = "bf16"
    # Uses bfloat16:
    # - faster
    # - less memory
    # - good stability on modern GPUs


    # -----------------------------
    # Reproducibility
    # -----------------------------
    seed = 0
    # Fixes randomness for reproducibility

# %%
def train_loop(config, 
               model, 
               noise_scheduler, 
               optimizer, 
               train_dataloader, 
               lr_scheduler):

    # -----------------------------
    # Device setup (GPU if available)
    # -----------------------------
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


    # -----------------------------
    # Initialize HuggingFace Accelerate
    # -----------------------------
    # Handles:
    # - mixed precision (bf16)
    # - gradient accumulation
    # - multi-GPU (if available)
    # - logging (TensorBoard)

    accelerator = Accelerator(
        mixed_precision=config.mixed_precision,
        gradient_accumulation_steps=config.gradient_accumulation_steps,
        log_with="tensorboard",
        project_dir=os.path.join(config.output_dir, "logs"),
    )

    # Only run setup/logging once (important for multi-GPU)
    if accelerator.is_main_process:
        if config.output_dir is not None:
            os.makedirs(config.output_dir, exist_ok=True)

        # Start TensorBoard logging
        accelerator.init_trackers("train_example")
        

    # -----------------------------
    # Prepare objects for acceleration
    # -----------------------------
    # This moves everything to the correct device and wraps it
    # for distributed/mixed precision training

    model, optimizer, train_dataloader, lr_scheduler = accelerator.prepare(
        model, optimizer, train_dataloader, lr_scheduler
    )


    # -----------------------------
    # Checkpoint setup
    # -----------------------------
    checkpt_dir = os.path.join(config.output_dir, 'checkpoint')

    if not os.path.exists(checkpt_dir):
        os.makedirs(checkpt_dir, exist_ok=True)

    # Ensure LR scheduler state is saved in checkpoints
    accelerator.register_for_checkpointing(lr_scheduler)

    global_step = 0


    # =============================
    # TRAINING LOOP
    # =============================
    for epoch in range(config.num_epochs):

        # Progress bar
        progress_bar = tqdm(
            total=len(train_dataloader),
            disable=not accelerator.is_local_main_process
        )
        progress_bar.set_description(f"Epoch {epoch}")


        # -----------------------------
        # Loop over batches
        # -----------------------------
        for step, batch in enumerate(train_dataloader):

            # -----------------------------------------
            # Split input into:
            # - condition (past timesteps)
            # - target (current timestep)
            # -----------------------------------------

            # shape: (B, 3, H, W)
            condition_images = batch['data'][:, 0:3, :, :] \
                .detach().to(torch.bfloat16).to(device)

            # shape: (B, 1, H, W)
            clean_images = batch['data'][:, 3:4, :, :] \
                .detach().to(torch.bfloat16).to(device)


            # -----------------------------------------
            # Sample noise
            # -----------------------------------------
            # Same shape as target image
            noise = torch.randn(clean_images.shape, device=clean_images.device)

            bs = clean_images.shape[0]


            # -----------------------------------------
            # Sample random diffusion timestep
            # -----------------------------------------
            # Each image gets a random noise level

            timesteps = torch.randint(
                0,
                noise_scheduler.config.num_train_timesteps,
                (bs,),
                device=clean_images.device,
                dtype=torch.int64
            ).to(device)


            # -----------------------------------------
            # Forward diffusion (add noise)
            # -----------------------------------------
            # x_t = sqrt(alpha_t)*x_0 + sqrt(1-alpha_t)*noise

            noisy_images = noise_scheduler.add_noise(
                clean_images,
                noise,
                timesteps
            )


            # -----------------------------------------
            # Gradient accumulation context
            # -----------------------------------------
            with accelerator.accumulate(model):

                # -------------------------------------
                # Prepare model input
                # -------------------------------------
                # Concatenate:
                # - noisy target (1 channel)
                # - condition (3 channels)
                #
                # Result: (B, 4, H, W)

                x_t = torch.cat([noisy_images, condition_images], dim=1)


                # -------------------------------------
                # Predict noise
                # -------------------------------------
                # Model tries to recover the noise that was added

                noise_pred = model(x_t, timesteps, return_dict=False)[0]


                # -------------------------------------
                # Loss: MSE between predicted and true noise
                # -------------------------------------
                loss = F.mse_loss(noise_pred, noise)


                # Backpropagation
                accelerator.backward(loss)


                # Gradient clipping (stability)
                if accelerator.sync_gradients:
                    accelerator.clip_grad_norm_(model.parameters(), 1.0)


                # Optimizer step
                optimizer.step()

                # Update learning rate
                lr_scheduler.step()

                # Reset gradients
                optimizer.zero_grad()


            # -----------------------------
            # Logging
            # -----------------------------
            progress_bar.update(1)

            logs = {
                "loss": loss.detach().item(),
                "lr": lr_scheduler.get_last_lr()[0],
                "step": global_step
            }

            progress_bar.set_postfix(**logs)
            accelerator.log(logs, step=global_step)

            global_step += 1


        # =============================
        # End of epoch: Save model
        # =============================
        if accelerator.is_main_process:

            # Wrap model into a pipeline for inference
            pipeline = DDPMPipeline(
                unet=accelerator.unwrap_model(model),
                scheduler=noise_scheduler
            )

            # Save checkpoint periodically
            if (epoch + 1) % config.save_model_epochs == 0 or epoch == config.num_epochs - 1:

                epoch_ckpt_dir = os.path.join(
                    config.output_dir,
                    f"checkpoint/epoch_{epoch+1:04d}"
                )

                # Save full training state
                accelerator.save_state(epoch_ckpt_dir)

                # Save model for inference
                pipeline.save_pretrained(epoch_ckpt_dir)

# %%
# -----------------------------
# Create config object
# -----------------------------
config = TrainingConfig()


# -----------------------------
# Device setup (GPU if available)
# -----------------------------
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


# -----------------------------
# Data directory
# -----------------------------
input_dir = '/scratch/nf33/cd3022/pyearth'


# -----------------------------
# Load normalization stats
# -----------------------------
with open('/scratch/nf33/cd3022/pyearth/min_max.json', 'r') as f:
    stats = json.load(f)

    # NOTE: using bfloat16 here (matches training precision)
    min_vals = torch.tensor(stats['min'], dtype=torch.bfloat16)
    max_vals = torch.tensor(stats['max'], dtype=torch.bfloat16)


# -----------------------------
# Build dataset
# -----------------------------
data_files = glob.glob(os.path.join(input_dir, '*.pt'))

dataset = LazyDatasetList(
    data_files,
    transform=MinMaxToMinusOneOne(min_vals, max_vals)
)


# -----------------------------
# Create DataLoader
# -----------------------------
train_dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=config.train_batch_size,
    shuffle=True,   # IMPORTANT: now shuffling for training
)


# -----------------------------
# Define the UNet model
# -----------------------------
model = UNet2DModel(

    # Spatial resolution (must match your data: 64x64)
    sample_size=config.image_size,

    # Input channels = 4
    # (1 noisy target + 3 conditioning frames)
    in_channels=config.in_channels,

    # Output channels = 1
    # (predict noise for target frame only)
    out_channels=config.out_channels,

    # Number of ResNet layers per block
    layers_per_block=2,

    # Channel sizes at each resolution level
    block_out_channels=(32, 64, 128, 256),

    # Downsampling path (encoder)
    down_block_types=(
        "DownBlock2D",  
        "DownBlock2D",
        "AttnDownBlock2D",  # includes attention
        "DownBlock2D",
    ),

    # Upsampling path (decoder)
    up_block_types=(
        "UpBlock2D", 
        "AttnUpBlock2D",   # attention here too
        "UpBlock2D",
        "UpBlock2D",
    ),

).to(device)


# -----------------------------
# Diffusion noise scheduler
# -----------------------------
noise_scheduler = DDPMScheduler(
    num_train_timesteps=1000  # standard DDPM setup
)


# -----------------------------
# Optimizer
# -----------------------------
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=config.learning_rate
)


# -----------------------------
# Learning rate scheduler
# -----------------------------
lr_scheduler = get_cosine_schedule_with_warmup(
    optimizer=optimizer,
    num_warmup_steps=config.lr_warmup_steps,

    # total number of training steps
    num_training_steps=(len(train_dataloader) * config.num_epochs),
)


# -----------------------------
# Bundle everything into args
# -----------------------------
# (used later to launch training)
args = (
    config,
    model,
    noise_scheduler,
    optimizer,
    train_dataloader,
    lr_scheduler
)
# Out:
# /jobfs/163255815.gadi-pbs/ipykernel_4024923/3393117095.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.min_vals = torch.tensor(min_vals).view(-1, 1, 1)
# /jobfs/163255815.gadi-pbs/ipykernel_4024923/3393117095.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.max_vals = torch.tensor(max_vals).view(-1, 1, 1)

# %%
# %%capture
# Jupyter magic: suppresses all output from this cell
# (useful because training logs can be very verbose)

# -----------------------------
# Start training
# -----------------------------
# Launches the training loop using HuggingFace Accelerate

notebook_launcher(
    train_loop,   # function to run (your training loop)
    args,         # arguments passed into train_loop
    num_processes=1  # number of parallel processes (1 = single GPU/CPU)
)
# Out:
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
