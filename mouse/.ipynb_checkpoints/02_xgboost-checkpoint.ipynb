# %% [markdown]
# # XGBoost

# %% [markdown]
# - Read in tabular data
# - Define predictor and target variables
# - Train XGBoost model

# %%
from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from dask.distributed import Client
import dask.dataframe as dd
import xgboost.dask as dxgb

import os
import sys
import yaml

sys.path.append('/home/548/cd3022/repos/solar-nowcast/modules')
import data_transform
from xgb_preprocess import prepare_data

from sklearn.metrics import mean_squared_error

# %%
client = Client()
client

# %%
config_name = 'vanilla'
# Get configurations from yaml file
with open(f"/home/548/cd3022/repos/solar-nowcast/configs/mouse/{config_name}.yaml") as f:
    config = yaml.safe_load(f)
# Model
model_name = config["model"]["name"]
forecast_lead = config["model"]["forecast_lead"]
# Parameters
random_state = config["model"]["parameters"]["random_state"]
n_estimators = config["model"]["parameters"]["n_estimators"]
early_stopping_rounds = config["model"]["parameters"]["early_stopping_rounds"]
learning_rate = config["model"]["parameters"]["learning_rate"]
eval_metric = config["model"]["parameters"]["eval_metric"]

# Data
X_vars = config["data"]["predictors"]
target = config["data"]["target"]
y_var = f'{target}_t{forecast_lead}'
all_vars = X_vars + [y_var]

# %%
data_path = Path('/scratch/er8/cd3022/xgb_datasets/')

train_files = []
test_files = []

for f in data_path.glob("all_training_month*"):
    month = f.name.split("_")[-1][:2]  # adjust to your naming

    if month in ['02', '06', '10']:
        test_files.append(str(f))
    else:
        train_files.append(str(f))

df_train = (
    dd.read_parquet(train_files, columns=all_vars)
    .astype("float32")
    .repartition(partition_size="256MB")
    .persist()
)

df_test = (
    dd.read_parquet(test_files, columns=all_vars)
    .astype("float32")
    .repartition(partition_size="256MB")
    .persist()
)

# %%
X_train = df_train[X_vars]
y_train = df_train[y_var]

X_test = df_test[X_vars]
y_test = df_test[y_var]

# smaller train set for evaluation
train_monitor = df_train.sample(frac=0.05)
X_train_monitor = train_monitor[X_vars]
y_train_monitor = train_monitor[y_var]

# %%
# DEFINE MODEL
# model = xgb.XGBRegressor(
#     random_state=random_state,
#     n_estimators=n_estimators,
#     early_stopping_rounds=early_stopping_rounds,
#     learning_rate=learning_rate,
#     eval_metric=eval_metric,
# )

# # TRAINING
# model.fit(
#     X_train, y_train,
#     eval_set=[(X_train, y_train), (X_test, y_test)],
#     verbose=True
# )

# MODEL
model = dxgb.DaskXGBRegressor(
    random_state=random_state,
    n_estimators=n_estimators,
    learning_rate=learning_rate,
    early_stopping_rounds=early_stopping_rounds,
    eval_metric=eval_metric,
    tree_method="hist",
)

# TRAIN
model.fit(
    X_train,
    y_train,
    eval_set=[
        (X_train_monitor, y_train_monitor),
        (X_test, y_test),
    ],
    verbose=False,
)
# Out:
# [15:24:53] Task [xgboost.dask-3]:tcp://127.0.0.1:38747 got rank 3[15:24:53] Task [xgboost.dask-2]:tcp://127.0.0.1:36221 got rank 2
#
# [15:24:53] Task [xgboost.dask-1]:tcp://127.0.0.1:43981 got rank 1[15:24:53] Task [xgboost.dask-4]:tcp://127.0.0.1:36271 got rank 4
#
# [15:24:53] Task [xgboost.dask-0]:tcp://127.0.0.1:44543 got rank 0
# [15:28:01] [115]	validation_0-rmse:0.15549	validation_1-rmse:0.18753
# [15:28:02] [116]	validation_0-rmse:0.15541	validation_1-rmse:0.18753
# [15:28:04] [117]	validation_0-rmse:0.15534	validation_1-rmse:0.18753
# [15:28:05] [118]	validation_0-rmse:0.15528	validation_1-rmse:0.18753
# [15:28:06] [119]	validation_0-rmse:0.15522	validation_1-rmse:0.18753
# [15:28:07] [120]	validation_0-rmse:0.15517	validation_1-rmse:0.18753
# [15:28:09] [121]	validation_0-rmse:0.15510	validation_1-rmse:0.18752
# [15:28:10] [122]	validation_0-rmse:0.15504	validation_1-rmse:0.18750
# [15:28:11] [123]	validation_0-rmse:0.15499	validation_1-rmse:0.18750
# [15:28:13] [124]	validation_0-rmse:0.15494	validation_1-rmse:0.18748
# [15:28:14] [125]	validation_0-rmse:0.15489	validation_1-rmse:0.18748
# [15:28:15] [126]	validation_0-rmse:0.15483	validation_1-rmse:0.18747
# [15:28:16] [127]	validation_0-rmse:0.15476	validation_1-rmse:0.18745
# [15:28:17] [128]	validation_0-rmse:0.15470	validation_1-rmse:0.18746
# [15:28:19] [129]	validation_0-rmse:0.15464	validation_1-rmse:0.18744
# [15:28:20] [130]	validation_0-rmse:0.15459	validation_1-rmse:0.18745
# [15:28:21] [131]	validation_0-rmse:0.15453	validation_1-rmse:0.18747
# [15:28:22] [132]	validation_0-rmse:0.15447	validation_1-rmse:0.18748
# [15:28:23] [133]	validation_0-rmse:0.15442	validation_1-rmse:0.18750
# [15:28:25] [134]	validation_0-rmse:0.15436	validation_1-rmse:0.18750
# [15:28:26] [135]	validation_0-rmse:0.15430	validation_1-rmse:0.18750
# [15:28:27] [136]	validation_0-rmse:0.15426	validation_1-rmse:0.18748
# [15:28:28] [137]	validation_0-rmse:0.15421	validation_1-rmse:0.18749
# [15:28:30] [138]	validation_0-rmse:0.15417	validation_1-rmse:0.18749
# [15:28:31] [139]	validation_0-rmse:0.15412	validation_1-rmse:0.18750
# [15:28:32] [140]	validation_0-rmse:0.15408	validation_1-rmse:0.18749
# [15:28:33] [141]	validation_0-rmse:0.15403	validation_1-rmse:0.18751
# [15:28:35] [142]	validation_0-rmse:0.15399	validation_1-rmse:0.18751
# [15:28:36] [143]	validation_0-rmse:0.15394	validation_1-rmse:0.18752
# [15:28:37] [144]	validation_0-rmse:0.15390	validation_1-rmse:0.18754
# DaskXGBRegressor(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bynode=None,
#                  colsample_bytree=None, device=None, early_stopping_rounds=50,
#                  enable_categorical=False, eval_metric='rmse',
#                  feature_types=None, feature_weights=None, gamma=None,
#                  grow_policy=None, importance_type=None,
#                  interaction_constraints=None, learning_rate=0.03, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  multi_strategy=None, n_estimators=2000, n_jobs=None,
#                  num_parallel_tree=None, ...)

# %%
results = model.evals_result()

train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

plt.figure()
plt.plot(train_loss, label='Train RMSE')
plt.plot(val_loss, label='Validation RMSE')

plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %%
# Predict on test set
y_pred = model.predict(X_test)

# %%
# Quick evaluation of model performance using correlation and RMSE
correlation = np.corrcoef(y_test, y_pred)[0, 1]
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Correlation between predicted and actual values: {correlation:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
# Out:
# Correlation between predicted and actual values: 0.714
# Root Mean Squared Error (RMSE): 0.187

# %%
model.save_model(f"/scratch/er8/cd3022/xgb_models/{model_name}.json")
