# %% [markdown]
# # XGBoost

# %% [markdown]
# - Read in tabular data
# - Define predictor and target variables
# - Train XGBoost model

# %%
import xgboost as xgb

from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import dask.dataframe as dd
import matplotlib.pyplot as plt

import os
import sys
import yaml

sys.path.append('/home/548/cd3022/repos/solar-nowcast/modules')
import data_transform
from xgb_preprocess import prepare_data

from sklearn.metrics import mean_squared_error

# %%
config_name = 'vanilla'
# Get configurations from yaml file
with open("/home/548/cd3022/repos/solar-nowcast/configs/mouse/basic.yaml") as f:
    config = yaml.safe_load(f)
# Model
model_name = config["model"]["name"]
forecast_lead = config["model"]["forecast_lead"]
# Parameters
random_state = config["model"]["parameters"]["random_state"]
n_estimators = config["model"]["parameters"]["n_estimators"]
early_stopping_rounds = config["model"]["parameters"]["early_stopping_rounds"]
learning_rate = config["model"]["parameters"]["learning_rate"]
eval_metric = config["model"]["parameters"]["eval_metric"]

# Data
X_vars = config["data"]["predictors"]
target = config["data"]["target"]
y_var = f'{target}_t{forecast_lead}'

# %%
data_path = Path('/scratch/er8/cd3022/xgb_datasets/')
# df_train = pd.read_parquet(data_path / "train_months.parquet", columns=X_vars + [target, y_var])
# df_test = pd.read_parquet(data_path / "test_months.parquet", columns=X_vars + [target, y_var])

df_train = dd.read_parquet(data_path / "train_months.parquet", columns=X_vars + [y_var])
df_test = dd.read_parquet(data_path / "test_months.parquet", columns=X_vars + [y_var])

# %%
X_train, y_train = prepare_data(
    df=df_train,
    X=X_vars,
    y=y_var,
)

X_test, y_test = prepare_data(
    df=df_test,
    X=X_vars,
    y=y_var,
)

# %%
# DEFINE MODEL
model = xgb.XGBRegressor(
    random_state=random_state,
    n_estimators=n_estimators,
    early_stopping_rounds=early_stopping_rounds,
    learning_rate=learning_rate,
    eval_metric=eval_metric,
)

# TRAINING
model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-rmse:16.74341	validation_1-rmse:19.25805
# [1]	validation_0-rmse:16.59084	validation_1-rmse:19.11556
# [2]	validation_0-rmse:16.44884	validation_1-rmse:18.98782
# [3]	validation_0-rmse:16.31944	validation_1-rmse:18.87058
# [4]	validation_0-rmse:16.20220	validation_1-rmse:18.76377
# [5]	validation_0-rmse:16.09130	validation_1-rmse:18.66893
# [6]	validation_0-rmse:15.99100	validation_1-rmse:18.58192
# [7]	validation_0-rmse:15.89756	validation_1-rmse:18.50379
# [8]	validation_0-rmse:15.81410	validation_1-rmse:18.43018
# [9]	validation_0-rmse:15.73620	validation_1-rmse:18.36403
# [10]	validation_0-rmse:15.66400	validation_1-rmse:18.30470
# [11]	validation_0-rmse:15.59769	validation_1-rmse:18.25295
# [12]	validation_0-rmse:15.53775	validation_1-rmse:18.20345
# [13]	validation_0-rmse:15.48192	validation_1-rmse:18.16066
# [14]	validation_0-rmse:15.43054	validation_1-rmse:18.11996
# [15]	validation_0-rmse:15.38174	validation_1-rmse:18.08100
# [16]	validation_0-rmse:15.33613	validation_1-rmse:18.04589
# [17]	validation_0-rmse:15.29569	validation_1-rmse:18.01510
# [18]	validation_0-rmse:15.25760	validation_1-rmse:17.98702
# [19]	validation_0-rmse:15.22128	validation_1-rmse:17.95825
# [20]	validation_0-rmse:15.18879	validation_1-rmse:17.93383
# [21]	validation_0-rmse:15.15727	validation_1-rmse:17.91047
# [22]	validation_0-rmse:15.12788	validation_1-rmse:17.89171
# [23]	validation_0-rmse:15.10128	validation_1-rmse:17.87640
# [24]	validation_0-rmse:15.07701	validation_1-rmse:17.86067
# [25]	validation_0-rmse:15.05383	validation_1-rmse:17.84716
# [26]	validation_0-rmse:15.03241	validation_1-rmse:17.83599
# [27]	validation_0-rmse:15.01294	validation_1-rmse:17.82536
# [28]	validation_0-rmse:14.99518	validation_1-rmse:17.81592
# [29]	validation_0-rmse:14.97763	validation_1-rmse:17.80620
# [30]	validation_0-rmse:14.96058	validation_1-rmse:17.79564
# [31]	validation_0-rmse:14.94443	validation_1-rmse:17.78733
# [32]	validation_0-rmse:14.92939	validation_1-rmse:17.77970
# [33]	validation_0-rmse:14.91608	validation_1-rmse:17.77375
# [34]	validation_0-rmse:14.90247	validation_1-rmse:17.76495
# [35]	validation_0-rmse:14.89027	validation_1-rmse:17.76107
# [36]	validation_0-rmse:14.87954	validation_1-rmse:17.75685
# [37]	validation_0-rmse:14.86830	validation_1-rmse:17.75100
# [38]	validation_0-rmse:14.85822	validation_1-rmse:17.74758
# [39]	validation_0-rmse:14.84905	validation_1-rmse:17.74401
# [40]	validation_0-rmse:14.83833	validation_1-rmse:17.74142
# [41]	validation_0-rmse:14.83000	validation_1-rmse:17.73906
# [42]	validation_0-rmse:14.82234	validation_1-rmse:17.73789
# [43]	validation_0-rmse:14.81306	validation_1-rmse:17.73536
# [44]	validation_0-rmse:14.80466	validation_1-rmse:17.73429
# [45]	validation_0-rmse:14.79780	validation_1-rmse:17.73297
# [46]	validation_0-rmse:14.79036	validation_1-rmse:17.73323
# [47]	validation_0-rmse:14.78329	validation_1-rmse:17.73326
# [48]	validation_0-rmse:14.77689	validation_1-rmse:17.73272
# [49]	validation_0-rmse:14.77122	validation_1-rmse:17.73291
# [50]	validation_0-rmse:14.76534	validation_1-rmse:17.73210
# [51]	validation_0-rmse:14.75884	validation_1-rmse:17.73171
# [52]	validation_0-rmse:14.75356	validation_1-rmse:17.73059
# [53]	validation_0-rmse:14.74787	validation_1-rmse:17.73164
# [54]	validation_0-rmse:14.74256	validation_1-rmse:17.73186
# [55]	validation_0-rmse:14.73681	validation_1-rmse:17.73250
# [56]	validation_0-rmse:14.73192	validation_1-rmse:17.73221
# [57]	validation_0-rmse:14.72784	validation_1-rmse:17.73164
# [58]	validation_0-rmse:14.72240	validation_1-rmse:17.73005
# [59]	validation_0-rmse:14.71781	validation_1-rmse:17.73020
# [60]	validation_0-rmse:14.71254	validation_1-rmse:17.73163
# [61]	validation_0-rmse:14.70845	validation_1-rmse:17.73145
# [62]	validation_0-rmse:14.70401	validation_1-rmse:17.73109
# [63]	validation_0-rmse:14.70002	validation_1-rmse:17.73127
# [64]	validation_0-rmse:14.69505	validation_1-rmse:17.73277
# [65]	validation_0-rmse:14.69164	validation_1-rmse:17.73452
# [66]	validation_0-rmse:14.68829	validation_1-rmse:17.73425
# [67]	validation_0-rmse:14.68580	validation_1-rmse:17.73488
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=10,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
results = model.evals_result()

train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

plt.figure()
plt.plot(train_loss, label='Train RMSE')
plt.plot(val_loss, label='Validation RMSE')

plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %%
# Predict on test set
y_pred = model.predict(X_test)

# %%
# Quick evaluation of model performance using correlation and RMSE
correlation = np.corrcoef(y_test['cloud_optical_depth_t1'], y_pred)[0, 1]
rmse = np.sqrt(mean_squared_error(y_test['cloud_optical_depth_t1'], y_pred))

print(f"Correlation between predicted and actual values: {correlation:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
# Out:
# Correlation between predicted and actual values: 0.470
# Root Mean Squared Error (RMSE): 17.127

# %%
model.save_model(f"/scratch/er8/cd3022/xgb_models/{model_name}_no_log.json")
