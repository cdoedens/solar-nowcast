# %% [markdown]
# # XGBoost

# %% [markdown]
# - Read in tabular data
# - Define predictor and target variables
# - Train XGBoost model

# %%
import xgboost as xgb

from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys
import yaml

sys.path.append('/home/548/cd3022/repos/solar-nowcast/modules')
import data_transform
from xgb_preprocessing import prepare_data

from sklearn.metrics import mean_squared_error

# %%
data_path = Path('/scratch/er8/cd3022/xgb_datasets/')
df2 = pd.concat(
    pd.read_parquet(f)
    for f in data_path.glob('*all_training_2*')
)

# %%
df2.shape[0] / df.shape[0]
# Out:
# 0.4013071020353459

# %%
df.shape
# Out:
# (71807401, 28)

# %%
# READ PARQUET TABULAR DATA
data_path = Path('/scratch/er8/cd3022/xgb_datasets/')
df = pd.concat(
    pd.read_parquet(f)
    for f in data_path.glob('*all_training_BAR-C*')
)

# %%
df.columns
# Out:
# Index(['surface_global_irradiance', 'cloud_optical_depth', 'solar_elevation',
#        'channel_0003_scaled_radiance', 'channel_0004_scaled_radiance',
#        'channel_0005_scaled_radiance', 'channel_0007_brightness_temperature',
#        'channel_0008_brightness_temperature',
#        'channel_0009_brightness_temperature',
#        'channel_0011_brightness_temperature',
#        'channel_0013_brightness_temperature',
#        'channel_0015_brightness_temperature', 'huss', 'hus850', 'hus700',
#        'hus500', 'psl', 'tas', 'ta850', 'ta700', 'ta500',
#        'cloud_optical_depth_t1', 'cloud_optical_depth_t2',
#        'cloud_optical_depth_t3', 'cloud_optical_depth_t4',
#        'cloud_optical_depth_t5', 'cloud_optical_depth_t6'],
#       dtype='object')

# %%
# Based off NWCSAF cloud retrieval algorithm requirements
df['channel_0013_0015_difference'] = df['channel_0013_brightness_temperature'] - df['channel_0015_brightness_temperature']
df['channel_0011_0013_difference'] = df['channel_0011_brightness_temperature'] - df['channel_0013_brightness_temperature']
df['channel_0007_0013_difference'] = df['channel_0007_brightness_temperature'] - df['channel_0013_brightness_temperature']

# %%
with open("/home/548/cd3022/repos/solar-nowcast/configs/mouse/original.yaml") as f:
    config = yaml.safe_load(f)

model_name = config["model"]["name"]
forecast_lead = config["model"]["forecast_lead"]
test_months = config["model"]["test_months"]
X_vars = config["data"]["predictors"]
target = config["data"]["target"]
y_var = f'{target}_t{forecast_lead}'

# %%
X_train, X_test, y_train, y_test = prepare_data(
    df=df,
    X=X_vars,
    y=y_var,
    test_months=test_months
)

# %%
# APPLY LOG TRANSFORM TO CLOUD OPTICAL DEPTH

# X_train['cloud_optical_depth'] = data_transform.log_transform(X_train['cloud_optical_depth'])
# X_test['cloud_optical_depth']  = data_transform.log_transform(X_test['cloud_optical_depth'])

y_train_log = data_transform.log_transform(y_train)
y_test_log  = data_transform.log_transform(y_test)

# %%
# DEFINE MODEL
model = xgb.XGBRegressor(
    random_state=42,
    n_estimators=2000,
    early_stopping_rounds=50,
    learning_rate=0.03,
    eval_metric='rmse',
    # device='cuda'
)

# TRAINING
model.fit(
    X_train, y_train_log,
    eval_set=[(X_train, y_train_log), (X_test, y_test_log)],
    verbose=True
)
# Out:
# [0]	validation_0-rmse:1.85646	validation_1-rmse:1.82986
# [1]	validation_0-rmse:1.82446	validation_1-rmse:1.79984
# [50]	validation_0-rmse:1.19829	validation_1-rmse:1.25574
# [51]	validation_0-rmse:1.19487	validation_1-rmse:1.25441
# [52]	validation_0-rmse:1.19154	validation_1-rmse:1.25222
# [53]	validation_0-rmse:1.18839	validation_1-rmse:1.25001
# [54]	validation_0-rmse:1.18549	validation_1-rmse:1.24800
# [55]	validation_0-rmse:1.18263	validation_1-rmse:1.24606
# [56]	validation_0-rmse:1.17993	validation_1-rmse:1.24404
# [57]	validation_0-rmse:1.17722	validation_1-rmse:1.24225
# [58]	validation_0-rmse:1.17465	validation_1-rmse:1.24037
# [59]	validation_0-rmse:1.17210	validation_1-rmse:1.23866
# [60]	validation_0-rmse:1.16972	validation_1-rmse:1.23705
# [61]	validation_0-rmse:1.16746	validation_1-rmse:1.23655
# [62]	validation_0-rmse:1.16524	validation_1-rmse:1.23501
# [63]	validation_0-rmse:1.16310	validation_1-rmse:1.23369
# [64]	validation_0-rmse:1.16115	validation_1-rmse:1.23248
# [65]	validation_0-rmse:1.15912	validation_1-rmse:1.23124
# [66]	validation_0-rmse:1.15724	validation_1-rmse:1.23019
# [67]	validation_0-rmse:1.15536	validation_1-rmse:1.22886
# [68]	validation_0-rmse:1.15369	validation_1-rmse:1.22792
# [69]	validation_0-rmse:1.15191	validation_1-rmse:1.22683
# [70]	validation_0-rmse:1.15017	validation_1-rmse:1.22593
# [71]	validation_0-rmse:1.14866	validation_1-rmse:1.22502
# [72]	validation_0-rmse:1.14712	validation_1-rmse:1.22422
# [73]	validation_0-rmse:1.14565	validation_1-rmse:1.22339
# [74]	validation_0-rmse:1.14421	validation_1-rmse:1.22255
# [75]	validation_0-rmse:1.14288	validation_1-rmse:1.22171
# [76]	validation_0-rmse:1.14158	validation_1-rmse:1.22104
# [77]	validation_0-rmse:1.14013	validation_1-rmse:1.22049
# [78]	validation_0-rmse:1.13886	validation_1-rmse:1.21979
# [79]	validation_0-rmse:1.13763	validation_1-rmse:1.21910
# [80]	validation_0-rmse:1.13650	validation_1-rmse:1.21854
# [81]	validation_0-rmse:1.13540	validation_1-rmse:1.21807
# [82]	validation_0-rmse:1.13418	validation_1-rmse:1.21754
# [83]	validation_0-rmse:1.13308	validation_1-rmse:1.21712
# [84]	validation_0-rmse:1.13211	validation_1-rmse:1.21670
# [85]	validation_0-rmse:1.13119	validation_1-rmse:1.21625
# [86]	validation_0-rmse:1.13019	validation_1-rmse:1.21586
# [87]	validation_0-rmse:1.12921	validation_1-rmse:1.21522
# [88]	validation_0-rmse:1.12835	validation_1-rmse:1.21501
# [89]	validation_0-rmse:1.12740	validation_1-rmse:1.21463
# [90]	validation_0-rmse:1.12643	validation_1-rmse:1.21432
# [91]	validation_0-rmse:1.12556	validation_1-rmse:1.21414
# [92]	validation_0-rmse:1.12476	validation_1-rmse:1.21382
# [93]	validation_0-rmse:1.12397	validation_1-rmse:1.21354
# [94]	validation_0-rmse:1.12308	validation_1-rmse:1.21309
# [95]	validation_0-rmse:1.12236	validation_1-rmse:1.21315
# [96]	validation_0-rmse:1.12165	validation_1-rmse:1.21278
# [97]	validation_0-rmse:1.12099	validation_1-rmse:1.21295
# [98]	validation_0-rmse:1.12011	validation_1-rmse:1.21267
# [99]	validation_0-rmse:1.11933	validation_1-rmse:1.21219
# [100]	validation_0-rmse:1.11866	validation_1-rmse:1.21193
# [101]	validation_0-rmse:1.11787	validation_1-rmse:1.21145
# [102]	validation_0-rmse:1.11724	validation_1-rmse:1.21127
# [103]	validation_0-rmse:1.11668	validation_1-rmse:1.21112
# [104]	validation_0-rmse:1.11598	validation_1-rmse:1.21089
# [105]	validation_0-rmse:1.11529	validation_1-rmse:1.21059
# [106]	validation_0-rmse:1.11463	validation_1-rmse:1.21045
# [107]	validation_0-rmse:1.11400	validation_1-rmse:1.21041
# [108]	validation_0-rmse:1.11346	validation_1-rmse:1.21022
# [109]	validation_0-rmse:1.11284	validation_1-rmse:1.20994
# [110]	validation_0-rmse:1.11222	validation_1-rmse:1.20980
# [111]	validation_0-rmse:1.11162	validation_1-rmse:1.20968
# [112]	validation_0-rmse:1.11099	validation_1-rmse:1.20945
# [113]	validation_0-rmse:1.11039	validation_1-rmse:1.20940
# [114]	validation_0-rmse:1.10985	validation_1-rmse:1.20925
# [115]	validation_0-rmse:1.10930	validation_1-rmse:1.20918
# [116]	validation_0-rmse:1.10876	validation_1-rmse:1.20896
# [117]	validation_0-rmse:1.10825	validation_1-rmse:1.20886
# [118]	validation_0-rmse:1.10768	validation_1-rmse:1.20894
# [119]	validation_0-rmse:1.10698	validation_1-rmse:1.20863
# [120]	validation_0-rmse:1.10649	validation_1-rmse:1.20865
# [121]	validation_0-rmse:1.10584	validation_1-rmse:1.20850
# [122]	validation_0-rmse:1.10543	validation_1-rmse:1.20849
# [123]	validation_0-rmse:1.10495	validation_1-rmse:1.20859
# [124]	validation_0-rmse:1.10436	validation_1-rmse:1.20848
# [125]	validation_0-rmse:1.10390	validation_1-rmse:1.20876
# [126]	validation_0-rmse:1.10336	validation_1-rmse:1.20869
# [127]	validation_0-rmse:1.10297	validation_1-rmse:1.20905
# [128]	validation_0-rmse:1.10240	validation_1-rmse:1.20898
# [129]	validation_0-rmse:1.10200	validation_1-rmse:1.20898
# [130]	validation_0-rmse:1.10153	validation_1-rmse:1.20900
# [131]	validation_0-rmse:1.10111	validation_1-rmse:1.20898
# [132]	validation_0-rmse:1.10059	validation_1-rmse:1.20894
# [133]	validation_0-rmse:1.10016	validation_1-rmse:1.20933
# [134]	validation_0-rmse:1.09976	validation_1-rmse:1.20931
# [135]	validation_0-rmse:1.09928	validation_1-rmse:1.20926
# [136]	validation_0-rmse:1.09889	validation_1-rmse:1.20930
# [137]	validation_0-rmse:1.09849	validation_1-rmse:1.20946
# [138]	validation_0-rmse:1.09811	validation_1-rmse:1.20945
# [139]	validation_0-rmse:1.09769	validation_1-rmse:1.20917
# [140]	validation_0-rmse:1.09733	validation_1-rmse:1.20917
# [141]	validation_0-rmse:1.09694	validation_1-rmse:1.20894
# [142]	validation_0-rmse:1.09661	validation_1-rmse:1.20898
# [143]	validation_0-rmse:1.09622	validation_1-rmse:1.20938
# [144]	validation_0-rmse:1.09594	validation_1-rmse:1.20951
# [145]	validation_0-rmse:1.09561	validation_1-rmse:1.20935
# [146]	validation_0-rmse:1.09530	validation_1-rmse:1.20941
# [147]	validation_0-rmse:1.09498	validation_1-rmse:1.20965
# [148]	validation_0-rmse:1.09469	validation_1-rmse:1.20955
# [149]	validation_0-rmse:1.09431	validation_1-rmse:1.21006
# [150]	validation_0-rmse:1.09398	validation_1-rmse:1.21000
# [151]	validation_0-rmse:1.09369	validation_1-rmse:1.21003
# [152]	validation_0-rmse:1.09336	validation_1-rmse:1.21060
# [153]	validation_0-rmse:1.09307	validation_1-rmse:1.21058
# [154]	validation_0-rmse:1.09269	validation_1-rmse:1.21039
# [155]	validation_0-rmse:1.09229	validation_1-rmse:1.21039
# [156]	validation_0-rmse:1.09196	validation_1-rmse:1.21058
# [157]	validation_0-rmse:1.09167	validation_1-rmse:1.21060
# [158]	validation_0-rmse:1.09143	validation_1-rmse:1.21065
# [159]	validation_0-rmse:1.09119	validation_1-rmse:1.21067
# [160]	validation_0-rmse:1.09087	validation_1-rmse:1.21074
# [161]	validation_0-rmse:1.09052	validation_1-rmse:1.21101
# [162]	validation_0-rmse:1.09023	validation_1-rmse:1.21112
# [163]	validation_0-rmse:1.09003	validation_1-rmse:1.21133
# [164]	validation_0-rmse:1.08972	validation_1-rmse:1.21161
# [165]	validation_0-rmse:1.08946	validation_1-rmse:1.21164
# [166]	validation_0-rmse:1.08913	validation_1-rmse:1.21161
# [167]	validation_0-rmse:1.08895	validation_1-rmse:1.21185
# [168]	validation_0-rmse:1.08860	validation_1-rmse:1.21185
# [169]	validation_0-rmse:1.08837	validation_1-rmse:1.21182
# [170]	validation_0-rmse:1.08806	validation_1-rmse:1.21201
# [171]	validation_0-rmse:1.08775	validation_1-rmse:1.21208
# [172]	validation_0-rmse:1.08754	validation_1-rmse:1.21220
# [173]	validation_0-rmse:1.08719	validation_1-rmse:1.21219
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Predict on test set
y_pred = model.predict(X_test)

# Quick evaluation of model performance using correlation and RMSE
correlation = np.corrcoef(y_test_log['cloud_optical_depth_t1'], y_pred)[0, 1]
rmse = np.sqrt(mean_squared_error(y_test_log['cloud_optical_depth_t1'], y_pred))

print(f"Correlation between predicted and actual values: {correlation:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
# Out:
# Correlation between predicted and actual values: 0.681
# Root Mean Squared Error (RMSE): 1.579

# %%
model.save_model(f"/scratch/er8/cd3022/xgb_models/{model_name}.json")

# %% [markdown]
# # Validation

# %%
results = model.evals_result()

train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

plt.figure()
plt.plot(train_loss, label='Train RMSE')
plt.plot(val_loss, label='Validation RMSE')

plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %%
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6, 6))
ax[0,0].hist(y_train_log, bins=100)
ax[0,0].set_title("True-train")
ax[0,0].set_xlim(-3, 5)
ax[0,0].set_ylim(0, 800_000)

ax[0,1].hist(y_pred_train, bins=100)
ax[0,1].set_title("Prediction-train")
ax[0,1].set_xlim(-3, 5)
ax[0,1].set_ylim(0, 800_000)

ax[1,0].hist(y_test_log, bins=100)
ax[1,0].set_title("True-test")
ax[1,0].set_xlim(-3, 5)
ax[1,0].set_ylim(0, 800_000)

ax[1,1].hist(y_pred_test, bins=100)
ax[1,1].set_title("Prediction-test")
ax[1,1].set_xlim(-3, 5)
ax[1,1].set_ylim(0, 800_000)
