# %% [markdown]
# # XGBoost

# %% [markdown]
# - Read in tabular data
# - Define predictor and target variables
# - Train XGBoost model

# %%
import xgboost as xgb

from pathlib import Path
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
import sys

sys.path.append('/home/548/cd3022/repos/solar-nowcast/modules')
import data_transform

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# READ PARQUET TABULAR DATA

data_path = Path('/scratch/er8/cd3022/xgb_datasets/')
df = pd.concat(
    pd.read_parquet(f)
    for f in data_path.glob('*all_training*')
)

# ADD MONTH COLUMN TO USE FOR TRAIN/TEST SPLIT
df['month'] = df.index.get_level_values('time').month

# %%
# Based off NWCSAF cloud retrieval algorithm requirements
df['channel_0013_0015_difference'] = df['channel_0013_brightness_temperature'] - df['channel_0015_brightness_temperature']
df['channel_0011_0013_difference'] = df['channel_0011_brightness_temperature'] - df['channel_0013_brightness_temperature']
df['channel_0007_0013_difference'] = df['channel_0007_brightness_temperature'] - df['channel_0013_brightness_temperature']

# %%
df.columns
# Out:
# Index(['cloud_optical_depth', 'channel_0003_scaled_radiance',
#        'channel_0005_scaled_radiance', 'channel_0007_brightness_temperature',
#        'channel_0009_brightness_temperature',
#        'channel_0011_brightness_temperature',
#        'channel_0013_brightness_temperature',
#        'channel_0015_brightness_temperature', 'huss', 'hus850', 'hus700',
#        'hus500', 'ta850', 'ta700', 'ta500', 'RH24mean', 'MUEL', 'FZL', 'MULCL',
#        'dp850', 'dp700', 'dp500', 'KI', 'TCD', 'CCD', 'ATP',
#        'cloud_optical_depth_t1', 'cloud_optical_depth_t2',
#        'cloud_optical_depth_t3', 'cloud_optical_depth_t4',
#        'cloud_optical_depth_t5', 'cloud_optical_depth_t6', 'month',
#        'channel_0013_0015_difference', 'channel_0011_0013_difference',
#        'channel_0007_0013_difference'],
#       dtype='object')

# %%
# SPLIT INTO TRAIN AND TEST BASED OFF MONTH
test_months = [2, 6, 10]

train_df = df[~df['month'].isin(test_months)]
test_df  = df[df['month'].isin(test_months)]

# %%
# DEFINE PREDICTOR AND TARGET VARIABLES
# X_train = train_df.drop(columns=['cloud_optical_depth'])
# X_test = test_df.drop(columns=['cloud_optical_depth'])

# Including CoD for current time
X_train = train_df.copy()
X_test = test_df.copy()
for n in range(1, 7):
    X_train = X_train.drop(columns=[f'cloud_optical_depth_t{n}'])
    X_test = X_test.drop(columns=[f'cloud_optical_depth_t{n}'])

X_train = X_train.drop(columns=['month'])
X_test = X_test.drop(columns=['month'])

y_train = train_df[['cloud_optical_depth_t1']]
y_test = test_df[['cloud_optical_depth_t1']]

# # Dropping extra predictors to trim down model
# for lvl in ['500', '700', '850']:
#     X_train = X_train.drop(columns=[f'ta{lvl}'])
#     X_test = X_test.drop(columns=[f'ta{lvl}'])

#     X_train = X_train.drop(columns=[f'hus{lvl}'])
#     X_test = X_test.drop(columns=[f'hus{lvl}'])

#     X_train = X_train.drop(columns=[f'dp{lvl}'])
#     X_test = X_test.drop(columns=[f'dp{lvl}'])

# X_train = X_train.drop(columns=['huss'])
# X_test = X_test.drop(columns=['huss'])

# X_train = X_train.drop(columns=['channel_0005_scaled_radiance'])
# X_test = X_test.drop(columns=['channel_0005_scaled_radiance'])

# X_train = X_train.drop(columns=['channel_0007_brightness_temperature'])
# X_test = X_test.drop(columns=['channel_0007_brightness_temperature'])

# X_train = X_train.drop(columns=['channel_0009_brightness_temperature'])
# X_test = X_test.drop(columns=['channel_0009_brightness_temperature'])

# %%
X_train.columns
# Out:
# Index(['cloud_optical_depth', 'channel_0003_scaled_radiance',
#        'channel_0005_scaled_radiance', 'channel_0007_brightness_temperature',
#        'channel_0009_brightness_temperature',
#        'channel_0011_brightness_temperature',
#        'channel_0013_brightness_temperature',
#        'channel_0015_brightness_temperature', 'huss', 'hus850', 'hus700',
#        'hus500', 'ta850', 'ta700', 'ta500', 'RH24mean', 'MUEL', 'FZL', 'MULCL',
#        'dp850', 'dp700', 'dp500', 'KI', 'TCD', 'CCD', 'ATP',
#        'channel_0013_0015_difference', 'channel_0011_0013_difference',
#        'channel_0007_0013_difference'],
#       dtype='object')

# %%
# APPLY LOG TRANSFORM TO CLOUD OPTICAL DEPTH

y_train_log = data_transform.log_transform(y_train)
y_test_log  = data_transform.log_transform(y_test)

# %%
# SAVE DATASETS TO BE USED LATER
model_name = 'fat_model'
X_train.to_parquet(data_path / f'train_predictors_{model_name}.parquet')
y_train_log.to_parquet(data_path / f'train_target_{model_name}.parquet')

X_test.to_parquet(data_path / f'test_predictors_{model_name}.parquet')
y_test_log.to_parquet(data_path / f'test_target_{model_name}.parquet')

# %%
# DEFINE MODEL
model = xgb.XGBRegressor(
    random_state=42,
    n_estimators=2000,
    early_stopping_rounds=50,
    learning_rate=0.03,
    eval_metric='rmse',
    # device='cuda'
)

# TRAINING
model.fit(
    X_train, y_train_log,
    eval_set=[(X_train, y_train_log), (X_test, y_test_log)],
    verbose=True
)

# Predict on test set
y_pred = model.predict(X_test)

# Quick evaluation of model performance using correlation and RMSE
correlation = np.corrcoef(y_test_log, y_pred)[0, 1]
rmse = np.sqrt(mean_squared_error(y_test_log, y_pred))

print(f"Correlation between predicted and actual values: {correlation:.3f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.3f}")
# Out:
# [0]	validation_0-rmse:2.18512	validation_1-rmse:2.16121
# [1]	validation_0-rmse:2.15001	validation_1-rmse:2.13227
# [2]	validation_0-rmse:2.11638	validation_1-rmse:2.10507
# [3]	validation_0-rmse:2.08423	validation_1-rmse:2.07920
# [4]	validation_0-rmse:2.05341	validation_1-rmse:2.05500
# [5]	validation_0-rmse:2.02402	validation_1-rmse:2.03172
# [6]	validation_0-rmse:1.99584	validation_1-rmse:2.00928
# [7]	validation_0-rmse:1.96891	validation_1-rmse:1.98865
# [8]	validation_0-rmse:1.94320	validation_1-rmse:1.96828
# [9]	validation_0-rmse:1.91855	validation_1-rmse:1.94946
# [10]	validation_0-rmse:1.89509	validation_1-rmse:1.93175
# [11]	validation_0-rmse:1.87266	validation_1-rmse:1.91584
# [12]	validation_0-rmse:1.85121	validation_1-rmse:1.89921
# [13]	validation_0-rmse:1.83063	validation_1-rmse:1.88364
# [14]	validation_0-rmse:1.81115	validation_1-rmse:1.86912
# [15]	validation_0-rmse:1.79239	validation_1-rmse:1.85538
# [63]	validation_0-rmse:1.44798	validation_1-rmse:1.64628
# [64]	validation_0-rmse:1.44594	validation_1-rmse:1.64600
# [65]	validation_0-rmse:1.44394	validation_1-rmse:1.64551
# [66]	validation_0-rmse:1.44190	validation_1-rmse:1.64512
# [67]	validation_0-rmse:1.44004	validation_1-rmse:1.64472
# [68]	validation_0-rmse:1.43823	validation_1-rmse:1.64444
# [69]	validation_0-rmse:1.43661	validation_1-rmse:1.64426
# [70]	validation_0-rmse:1.43503	validation_1-rmse:1.64478
# [71]	validation_0-rmse:1.43340	validation_1-rmse:1.64418
# [72]	validation_0-rmse:1.43197	validation_1-rmse:1.64396
# [73]	validation_0-rmse:1.43058	validation_1-rmse:1.64419
# [74]	validation_0-rmse:1.42913	validation_1-rmse:1.64386
# [75]	validation_0-rmse:1.42776	validation_1-rmse:1.64372
# [76]	validation_0-rmse:1.42629	validation_1-rmse:1.64329
# [77]	validation_0-rmse:1.42494	validation_1-rmse:1.64289
# [78]	validation_0-rmse:1.42357	validation_1-rmse:1.64274
# [79]	validation_0-rmse:1.42236	validation_1-rmse:1.64267
# [80]	validation_0-rmse:1.42116	validation_1-rmse:1.64251
# [81]	validation_0-rmse:1.42010	validation_1-rmse:1.64236
# [82]	validation_0-rmse:1.41906	validation_1-rmse:1.64243
# [83]	validation_0-rmse:1.41810	validation_1-rmse:1.64264
# [84]	validation_0-rmse:1.41705	validation_1-rmse:1.64258
# [85]	validation_0-rmse:1.41618	validation_1-rmse:1.64250
# [86]	validation_0-rmse:1.41522	validation_1-rmse:1.64240
# [87]	validation_0-rmse:1.41434	validation_1-rmse:1.64209
# [88]	validation_0-rmse:1.41340	validation_1-rmse:1.64214
# [89]	validation_0-rmse:1.41237	validation_1-rmse:1.64208
# [90]	validation_0-rmse:1.41154	validation_1-rmse:1.64186
# [91]	validation_0-rmse:1.41067	validation_1-rmse:1.64198
# [92]	validation_0-rmse:1.40983	validation_1-rmse:1.64197
# [93]	validation_0-rmse:1.40911	validation_1-rmse:1.64224
# [94]	validation_0-rmse:1.40832	validation_1-rmse:1.64244
# [95]	validation_0-rmse:1.40762	validation_1-rmse:1.64263
# [96]	validation_0-rmse:1.40680	validation_1-rmse:1.64276
# [97]	validation_0-rmse:1.40609	validation_1-rmse:1.64274
# [98]	validation_0-rmse:1.40542	validation_1-rmse:1.64248
# [99]	validation_0-rmse:1.40481	validation_1-rmse:1.64282
# [100]	validation_0-rmse:1.40418	validation_1-rmse:1.64286
# [101]	validation_0-rmse:1.40353	validation_1-rmse:1.64314
# [102]	validation_0-rmse:1.40296	validation_1-rmse:1.64337
# [103]	validation_0-rmse:1.40228	validation_1-rmse:1.64356
# [104]	validation_0-rmse:1.40167	validation_1-rmse:1.64369
# [105]	validation_0-rmse:1.40085	validation_1-rmse:1.64380
# [106]	validation_0-rmse:1.40006	validation_1-rmse:1.64388
# [107]	validation_0-rmse:1.39948	validation_1-rmse:1.64424
# [108]	validation_0-rmse:1.39873	validation_1-rmse:1.64429
# [109]	validation_0-rmse:1.39803	validation_1-rmse:1.64444
# [110]	validation_0-rmse:1.39750	validation_1-rmse:1.64490
# [111]	validation_0-rmse:1.39678	validation_1-rmse:1.64490
# [112]	validation_0-rmse:1.39620	validation_1-rmse:1.64496
# [113]	validation_0-rmse:1.39554	validation_1-rmse:1.64502
# [114]	validation_0-rmse:1.39497	validation_1-rmse:1.64527
# [115]	validation_0-rmse:1.39446	validation_1-rmse:1.64601
# [116]	validation_0-rmse:1.39390	validation_1-rmse:1.64670
# [117]	validation_0-rmse:1.39331	validation_1-rmse:1.64747
# [118]	validation_0-rmse:1.39261	validation_1-rmse:1.64753
# [119]	validation_0-rmse:1.39202	validation_1-rmse:1.64772
# [120]	validation_0-rmse:1.39143	validation_1-rmse:1.64791
# [121]	validation_0-rmse:1.39083	validation_1-rmse:1.64849
# [122]	validation_0-rmse:1.39013	validation_1-rmse:1.64843
# [123]	validation_0-rmse:1.38951	validation_1-rmse:1.64859
# [124]	validation_0-rmse:1.38901	validation_1-rmse:1.64854
# [125]	validation_0-rmse:1.38852	validation_1-rmse:1.64867
# [126]	validation_0-rmse:1.38792	validation_1-rmse:1.64885
# [127]	validation_0-rmse:1.38729	validation_1-rmse:1.64882
# [128]	validation_0-rmse:1.38688	validation_1-rmse:1.64922
# [129]	validation_0-rmse:1.38637	validation_1-rmse:1.64924
# [130]	validation_0-rmse:1.38581	validation_1-rmse:1.64928
# [131]	validation_0-rmse:1.38533	validation_1-rmse:1.64915
# [132]	validation_0-rmse:1.38486	validation_1-rmse:1.64902
# [133]	validation_0-rmse:1.38438	validation_1-rmse:1.64914
# [134]	validation_0-rmse:1.38386	validation_1-rmse:1.64927
# [135]	validation_0-rmse:1.38339	validation_1-rmse:1.64925
# [136]	validation_0-rmse:1.38296	validation_1-rmse:1.64921
# [137]	validation_0-rmse:1.38246	validation_1-rmse:1.64924
# [138]	validation_0-rmse:1.38206	validation_1-rmse:1.64913
# [139]	validation_0-rmse:1.38160	validation_1-rmse:1.64910
# [140]	validation_0-rmse:1.38096	validation_1-rmse:1.64908
# Correlation between predicted and actual values: 0.661
# Root Mean Squared Error (RMSE): 1.642

# %%
model.save_model("/scratch/er8/cd3022/xgb_models/fat_model.json")

# %% [markdown]
# # Validation

# %%
results = model.evals_result()

train_loss = results['validation_0']['rmse']
val_loss = results['validation_1']['rmse']

plt.figure()
plt.plot(train_loss, label='Train RMSE')
plt.plot(val_loss, label='Validation RMSE')

plt.xlabel('Boosting Iterations')
plt.ylabel('RMSE')
plt.title('Training vs Validation Loss')
plt.legend()

plt.show()

# %%
y_pred_test = model.predict(X_test)
y_pred_train = model.predict(X_train)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(6, 6))
ax[0,0].hist(y_train_log, bins=100)
ax[0,0].set_title("True-train")
ax[0,0].set_xlim(-3, 5)
ax[0,0].set_ylim(0, 800_000)

ax[0,1].hist(y_pred_train, bins=100)
ax[0,1].set_title("Prediction-train")
ax[0,1].set_xlim(-3, 5)
ax[0,1].set_ylim(0, 800_000)

ax[1,0].hist(y_test_log, bins=100)
ax[1,0].set_title("True-test")
ax[1,0].set_xlim(-3, 5)
ax[1,0].set_ylim(0, 800_000)

ax[1,1].hist(y_pred_test, bins=100)
ax[1,1].set_title("Prediction-test")
ax[1,1].set_xlim(-3, 5)
ax[1,1].set_ylim(0, 800_000)
# Out:
# (0.0, 800000.0)
