# %%
import subprocess
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta


# First full month of data (Aug '15) to latest (Jan '25)
first = '2025-01-01'
num_batches = 12
days_per_batch = 5

first_dt = datetime.strptime(first, "%Y-%m-%d")
dates = []
for x in range(num_batches):
    start_dt = first_dt + relativedelta(months =  x)
    start_date = start_dt.strftime("%Y-%m-%d")
    dates.append(start_date)


for date in dates:
    
    # Generate a unique file name based on iteration
    joboutdir = '/home/548/cd3022/repos/solar-nowcast/jobs/'
    job_script_filename = joboutdir + f'xgb_alldata___{date}___{days_per_batch}.qsub'
    
    # Open the file for writing
    with open(job_script_filename, "w") as f3:
        f3.write('#!/bin/bash \n')
        f3.write('#PBS -l walltime=2:00:00 \n')
        f3.write('#PBS -l mem=96GB \n')
        f3.write('#PBS -l ncpus=48 \n')
        f3.write('#PBS -l jobfs=10GB \n')
        f3.write('#PBS -l storage=gdata/dk92+gdata/rt52+scratch/nf33+gdata/rv74+gdata/rq0+gdata/ra22+gdata/xp65+gdata/er8+scratch/er8+gdata/ob53 \n')
        f3.write('#PBS -l other=hyperthread \n')
        f3.write('#PBS -q normal \n')
        f3.write('#PBS -P er8 \n')
        f3.write(f'#PBS -o /home/548/cd3022/repos/solar-nowcast/logs/xgb_alldata___{date}___{days_per_batch}.oe \n')
        f3.write('#PBS -j oe \n')
        f3.write('cd /home/548/cd3022/repos/solar-nowcast \n') 
        f3.write('source env.sh \n')
        f3.write(f'python3 mouse/01_prepare_alldata.py {date} {days_per_batch}\n')


    # Submit the generated script to the job scheduler (PBS) using qsub
    try:
        # Run the qsub command and submit the script
        subprocess.run(['qsub', job_script_filename], check=True)
        print(f"Job script {job_script_filename} submitted successfully.")
    except subprocess.CalledProcessError as e:
        print(f"Error submitting job script {job_script_filename}: {e}")
# Out:
# 166946201.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-01-01___5.qsub submitted successfully.
# 166946202.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-02-01___5.qsub submitted successfully.
# 166946203.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-03-01___5.qsub submitted successfully.
# 166946204.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-04-01___5.qsub submitted successfully.
# 166946205.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-05-01___5.qsub submitted successfully.
# 166946206.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-06-01___5.qsub submitted successfully.
# 166946207.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-07-01___5.qsub submitted successfully.
# 166946208.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-08-01___5.qsub submitted successfully.
# 166946209.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-09-01___5.qsub submitted successfully.
# 166946210.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-10-01___5.qsub submitted successfully.
# 166946211.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-11-01___5.qsub submitted successfully.
# 166946212.gadi-pbs
# Job script /home/548/cd3022/repos/solar-nowcast/jobs/xgb_alldata___2025-12-01___5.qsub submitted successfully.

# %%
date
# Out:
# '01-12-2025'
